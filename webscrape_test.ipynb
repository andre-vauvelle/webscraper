# %%
import json
import os
from google_images_download import google_images_download

# %%
name = "upper_set_10000_related"
#"url":"https://www.google.com/search?sa=G&hl=en-GB&tbs=simg:CAEStgIJP6JcdIecE6saqgILEKjU2AQaBAgVCAgMCxCwjKcIGmIKYAgDEijvBckPmQ-aD5IPkA_1ID5QP7gWhAd0z_1yzqPYAt2jPbM9c03DOUIo06GjCtAz-Rba7c-7kGzxQ_1abFP6FKQvlmDKV7f77EPDemQncKq0Auhr4fwToGc5noWm74gBAwLEI6u_1ggaCgoICAESBHlTkIMMCxCd7cEJGpUBChsKCWRlbnRpc3RyedqliPYDCgoIL20vMDI3N2cKJAoRbWFjcm8gcGhvdG9ncmFwaHnapYj2AwsKCS9tLzAzcmJmNgoWCgNqYXfapYj2AwsKCS9tLzAxazlsagoXCgRuYWls2qWI9gMLCgkvbS8wMjNqNHIKHwoMY29sb3JmdWxuZXNz2qWI9gMLCgkvbS8wMzB6bGYM&q=dentistry&tbm=isch&ved=2ahUKEwiDu5PqwrHgAhXWThUIHVlaDsYQsw56BAgFEAE&biw=1280&bih=667"

response = google_images_download.googleimagesdownload()
arguments = {"limit":1000,
             "print_urls":True,
             "extract_metadata": True,
             "output_directory": name,
             "chromedriver": "/usr/local/bin/chromedriver",
             "related_images": True,
             "keywords":"occlusal"}   #creating list of arguments

with open(name+'.json', 'w') as outfile:
    json.dump(arguments, outfile)

paths = response.download(arguments)   #passing the arguments to the function)
# Out:
# Item no.: 1 --> Item name = occlusal
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Image URL: https://www.sunrisedentalsmile.com/assets/images/stock-occlusal_adjustment.jpg
# Completed Image ====> 1. stock-occlusal_adjustment.jpg
# Image URL: http://www.biomedres.info/articles-images/biomedres-occlusal-hypofunction-26-4-609-g005.png
# Completed Image ====> 2. biomedres-occlusal-hypofunction-26-4-609-g005.png
# Image URL: https://www.speareducation.com/spear-review/filemanager/userfiles/Courtney_Lavigne/dental_photography_figure_1.jpg
# Completed Image ====> 3. dental_photography_figure_1.jpg
# Image URL: https://aemstatic-ww2.azureedge.net/content/dam/diq/online-articles/2018/06/18Jun28BCspringer07.jpg
# Completed Image ====> 4. 18jun28bcspringer07.jpg
# Image URL: https://www.speareducation.com/spear-review/filemanager/userfiles/Gary_DeWood/occlusion_diagnosis_1.png
# ...

# %%
20 % 10
# Out:
# 0

# %%
round(0.002435463554)
# Out:
# 0
